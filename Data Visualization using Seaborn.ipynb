# %%
# !python3 -m pip install mitoinstaller

# %%
# !python3 -m mitoinstaller install

# %%
import pandas as pd
df = pd.read_csv('KUP_humid_temp_Feb21.csv')
df.head()

# %%
import mitosheet
mitosheet.sheet(df, view_df=True)
# Out:
# MitoWidget(analysis_data_json='{"analysisName": "UUID-9c3dbadb-7939-492c-96ad-be12327289b8", "code": {"imports…
