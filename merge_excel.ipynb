# %%
import pandas as pd
import numpy as np

# %%
# !ls..in
# Out:
# 'ls..in' is not recognized as an internal or external command,
# operable program or batch file.

# %%
import glob
glob.glob("C:\\Users\\nhungtth\\Downloads\\kqua\kqua*.xls")
# Out:
# ['C:\\Users\\nhungtth\\Downloads\\kqua\\kquabd.xls',
#  'C:\\Users\\nhungtth\\Downloads\\kqua\\kquach.xls',
#  'C:\\Users\\nhungtth\\Downloads\\kqua\\kquad1.xls',
#  'C:\\Users\\nhungtth\\Downloads\\kqua\\kquad2.xls',
#  'C:\\Users\\nhungtth\\Downloads\\kqua\\kquag1.xls',
#  'C:\\Users\\nhungtth\\Downloads\\kqua\\kquag2.xls',
#  'C:\\Users\\nhungtth\\Downloads\\kqua\\kquag3.xls',
#  'C:\\Users\\nhungtth\\Downloads\\kqua\\kquag4.xls',
#  'C:\\Users\\nhungtth\\Downloads\\kqua\\kquag5.xls',
#  'C:\\Users\\nhungtth\\Downloads\\kqua\\kquahc.xls',
#  'C:\\Users\\nhungtth\\Downloads\\kqua\\kquahm.xls',
#  'C:\\Users\\nhungtth\\Downloads\\kqua\\kquasp.xls',
#  'C:\\Users\\nhungtth\\Downloads\\kqua\\kquavt.xls']

# %%
all_data = pd.DataFrame()
for f in glob.glob("C:\\Users\\nhungtth\\Downloads\\kqua\kqua*.xls"):
    df = pd.read_excel(f)
    all_data = all_data.append(df,ignore_index=True)

# %%
all_data.describe()
# Out:
#            so_luong  gia_ke_hoach       don_gia    thanh_tien    ma_nha_thau  \
# count  3.552000e+03  3.552000e+03  2.184000e+03  3.552000e+03    3552.000000
# mean   1.454751e+05  9.166041e+05  1.599801e+05  5.417283e+08  719086.501408
# std    6.308514e+05  3.045795e+06  1.087133e+06  1.463263e+09      75.803110
# min    1.000000e+00  3.600000e+01  3.600000e+01  3.900000e+04  719001.000000
# 25%    4.075000e+02  3.214250e+03  1.915000e+03  3.360000e+07  719017.000000
# 50%    6.000000e+03  2.000000e+04  6.770000e+03  1.255956e+08  719063.000000
# 75%    5.689500e+04  1.913542e+05  3.446250e+04  4.202300e+08  719152.250000
# max    1.318750e+07  7.087500e+07  2.714038e+07  2.005266e+10  719255.000000
#
#               bvt19         bvt20         bvnh19         bvnh20  \
# count  3.552000e+03  3.552000e+03    3552.000000    3552.000000
# mean   8.096191e+03  7.634831e+03    3156.710304    2873.588119
# std    4.959160e+04  4.931541e+04   21151.048450   19380.215930
# ...

# %%
all_data.head()
# Out:
#      ma_so                                      ten_hoat_chat ham_luong  \
# 0  BD1.001  Acid zoledronic (dưới dạng Acid zoledronic mon...     100ml
# 1  BD1.002                                        Tocilizumab     200mg
# 2  BD1.011                                         Everolimus      10mg
# 3  BD1.012                                         Everolimus       5mg
# 4  BD1.013                                     Spironolactone     25 mg
#
#                                      dang_bao_che  \
# 0            Dung dịch truyền tĩnh mạch 5mg/100ml
# 1  Dung dịch đậm đặc để pha dung dịch tiêm truyền
# 2                                        Viên nén
# 3                                        Viên nén
# 4                                        Viên nén
#
#                    ten_thuoc_trung  \
# 0  Aclasta 5mg/100ml Inf 100ml 1's
# 1      Actemra 200mg 10ml Vial B/1
# 2         Afinitor Tab 10mg 3x10's
# 3          Afinitor Tab 5mg 3x10's
# 4         Aldactone Tab 25mg 100's
#
# ...

# %%
all_data.to_excel(r'C:\\Users\\nhungtth\\Downloads\\kqua\\combine.xls', index = False)
